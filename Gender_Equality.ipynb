# %% [markdown]
# # **Addressing the Issue of Gender Equality**

# %%
def create_data_set():
    """
    This function creates a data set code for gender_phil with the given values.
    
    Returns:
    str: The data set code for gender_phil
    """
    try:
        # Define the values for the data set
        country_name = "Philippines"
        country_iso3 = "PHL"
        year = "2015"
        indicator_name = "Firms with female top manager (% of firms)"
        indicator_code = "IC.FRM.FEMM.ZS"
        value = "29.9"
        
        # Create the data set code
        data_set_code = f"{country_name},{country_iso3},{year},{indicator_name},{indicator_code},{value}"
        
        # Return the data set code
        return data_set_code
    except Exception as e:
        # Log the error
        print(f"Error: {e}")
        return ""

# %%
gender_phil = [
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Firms with female top manager (% of firms)",
        "Indicator Code": "IC.FRM.FEMM.ZS",
        "Value": 29.9
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2009,
        "Indicator Name": "Firms with female top manager (% of firms)",
        "Indicator Code": "IC.FRM.FEMM.ZS",
        "Value": 32.7
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Firms with female participation in ownership (% of firms)",
        "Indicator Code": "IC.FRM.FEMO.ZS",
        "Value": 69.2
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2009,
        "Indicator Name": "Firms with female participation in ownership (% of firms)",
        "Indicator Code": "IC.FRM.FEMO.ZS",
        "Value": 69.4
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2019,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 98.89290619
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 99.26673126
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2013,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 98.81542969
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2008,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 98.49152374
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2003,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 96.58058929
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2000,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 95.72028351
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1994,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 96.28193665
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1990,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 96.87773895
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1980,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 92.46903229
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2019,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.010069966
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.00364995
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2013,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.014070034
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2008,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.014940023
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2003,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.031090021
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2000,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.013180017
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1994,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.004840016
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1990,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.006199956
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1980,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.015200019
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2019,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 97.89730835
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 98.90415192
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2013,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 97.4254303
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2008,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 97.01995087
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2003,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 93.57830048
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2000,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 93.54418182
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1994,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 95.12384033
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1990,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 95.33789063
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1980,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 91.02488708
    }
]

# %%
gender_phil = [
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Firms with female top manager (% of firms)",
        "Indicator Code": "IC.FRM.FEMM.ZS",
        "Value": 29.9
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2009,
        "Indicator Name": "Firms with female top manager (% of firms)",
        "Indicator Code": "IC.FRM.FEMM.ZS",
        "Value": 32.7
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Firms with female participation in ownership (% of firms)",
        "Indicator Code": "IC.FRM.FEMO.ZS",
        "Value": 69.2
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2009,
        "Indicator Name": "Firms with female participation in ownership (% of firms)",
        "Indicator Code": "IC.FRM.FEMO.ZS",
        "Value": 69.4
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2019,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 98.89290619
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 99.26673126
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2013,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 98.81542969
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2008,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 98.49152374
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2003,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 96.58058929
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2000,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 95.72028351
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1994,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 96.28193665
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1990,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 96.87773895
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1980,
        "Indicator Name": "Literacy rate, youth female (% of females ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.FE.ZS",
        "Value": 92.46903229
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2019,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.010069966
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.00364995
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2013,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.014070034
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2008,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.014940023
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2003,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.031090021
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2000,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.013180017
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1994,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.004840016
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1990,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.006199956
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1980,
        "Indicator Name": "Literacy rate, youth (ages 15-24), gender parity index (GPI)",
        "Indicator Code": "SE.ADT.1524.LT.FM.ZS",
        "Value": 1.015200019
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2019,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 97.89730835
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2015,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 98.90415192
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2013,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 97.4254303
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2008,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 97.01995087
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2003,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 93.57830048
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 2000,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 93.54418182
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1994,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 95.12384033
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1990,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 95.33789063
    },
    {
        "Country Name": "Philippines",
        "Country ISO3": "PHL",
        "Year": 1980,
        "Indicator Name": "Literacy rate, youth male (% of males ages 15-24)",
        "Indicator Code": "SE.ADT.1524.LT.MA.ZS",
        "Value": 91.02488708
    }
]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a list of gender equality indices
gender_equality_data = [0.647, 0.736, 0.563, 0.821, 0.672, 0.724, 0.615, 0.695, 0.582, 0.718]

# Create a list of corresponding years
year_data = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# Create a dictionary to store the data
data = {
    'Year': year_data,
    'Gender Equality Index': gender_equality_data
}

# Create a pandas DataFrame from the dictionary
df = pd.DataFrame(data)

# Plot a line graph for gender equality over the years
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Gender Equality Index'], marker='o')
plt.title('Gender Equality Index in the Philippines')
plt.xlabel('Year')
plt.ylabel('Gender Equality Index')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a list of gender data
gender_data = ['Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female']

# Create a list of corresponding regions in the Philippines
region_data = ['NCR', 'Visayas', 'Mindanao', 'Luzon', 'NCR', 'Visayas', 'Mindanao', 'Luzon', 'NCR', 'Visayas']

# Create a dictionary to store the data
data = {
    'Gender': gender_data,
    'Region': region_data
}

# Create a pandas DataFrame from the dictionary
df = pd.DataFrame(data)

# Count the number of occurrences for each gender
gender_counts = df['Gender'].value_counts()

# Plot a bar chart for gender distribution
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color=['blue', 'pink'])
plt.title('Gender Distribution in the Philippines')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = [
    ['Philippines', 'PHL', 2015, 'Firms with female top manager (% of firms)', 'IC.FRM.FEMM.ZS', 29.9],
    ['Philippines', 'PHL', 2009, 'Firms with female top manager (% of firms)', 'IC.FRM.FEMM.ZS', 32.7],
    ['Philippines', 'PHL', 2015, 'Firms with female participation in ownership (% of firms)', 'IC.FRM.FEMO.ZS', 69.2],
    ['Philippines', 'PHL', 2009, 'Firms with female participation in ownership (% of firms)', 'IC.FRM.FEMO.ZS', 69.4],
    ['Philippines', 'PHL', 2019, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 98.89290619],
    ['Philippines', 'PHL', 2015, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 99.26673126],
    ['Philippines', 'PHL', 2013, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 98.81542969],
    ['Philippines', 'PHL', 2008, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 98.49152374],
    ['Philippines', 'PHL', 2003, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 96.58058929],
    ['Philippines', 'PHL', 2000, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 95.72028351],
    ['Philippines', 'PHL', 1994, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 96.28193665],
    ['Philippines', 'PHL', 1990, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 96.87773895],
    ['Philippines', 'PHL', 1980, 'Literacy rate, youth female (% of females ages 15-24)', 'SE.ADT.1524.LT.FE.ZS', 92.46903229],
    ['Philippines', 'PHL', 2019, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.010069966],
    ['Philippines', 'PHL', 2015, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.00364995],
    ['Philippines', 'PHL', 2013, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.014070034],
    ['Philippines', 'PHL', 2008, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.014940023],
    ['Philippines', 'PHL', 2003, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.031090021],
    ['Philippines', 'PHL', 2000, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.013180017],
    ['Philippines', 'PHL', 1994, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.004840016],
    ['Philippines', 'PHL', 1990, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.006199956],
    ['Philippines', 'PHL', 1980, 'Literacy rate, youth (ages 15-24), gender parity index (GPI)', 'SE.ADT.1524.LT.FM.ZS', 1.015200019],
    ['Philippines', 'PHL', 2019, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 97.89730835]
]

# Create a pandas DataFrame from the data
df = pd.DataFrame(data, columns=['Country', 'ISO Code', 'Year', 'Indicator', 'Indicator Code', 'Value'])

# Filter the data for the desired indicators
filtered_df = df[(df['Indicator'].str.contains('Firms with female')) |
                  (df['Indicator'].str.contains('Literacy rate, youth'))]

# Pivot the DataFrame to reorganize the data for visualization
pivot_df = filtered_df.pivot(index='Year', columns='Indicator', values='Value')

# Plot the graphs
plt.figure(figsize=(12, 6))

# Plot for Firms with female top manager (% of firms)
plt.subplot(1, 2, 1)
plt.plot(pivot_df.index, pivot_df['Firms with female top manager (% of firms)'], marker='o')
plt.title('Firms with Female Top Manager (% of Firms)')
plt.xlabel('Year')
plt.ylabel('% of Firms')
plt.xticks(rotation=45)
plt.grid(True)

# Plot for Literacy rate, youth female (% of females ages 15-24)
plt.subplot(1, 2, 2)
plt.plot(pivot_df.index, pivot_df['Literacy rate, youth female (% of females ages 15-24)'], marker='o')
plt.title('Literacy Rate, Youth Female (% of Females Ages 15-24)')
plt.xlabel('Year')
plt.ylabel('%')
plt.xticks(rotation=45)
plt.grid(True)

# Adjust the layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = [
    ['Philippines', 'PHL', 2015, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 98.90415192],
    ['Philippines', 'PHL', 2013, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 97.4254303],
    ['Philippines', 'PHL', 2008, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 97.01995087],
    ['Philippines', 'PHL', 2003, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 93.57830048],
    ['Philippines', 'PHL', 2000, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 94.45825958],
    ['Philippines', 'PHL', 1994, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 95.81552124],
    ['Philippines', 'PHL', 1990, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 96.2767334],
    ['Philippines', 'PHL', 1980, 'Literacy rate, youth male (% of males ages 15-24)', 'SE.ADT.1524.LT.MA.ZS', 91.06330872],
    ['Philippines', 'PHL', 2019, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 96.85243225],
    ['Philippines', 'PHL', 2015, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 98.24175262],
    ['Philippines', 'PHL', 2013, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 96.78736115],
    ['Philippines', 'PHL', 2008, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 95.82563019],
    ['Philippines', 'PHL', 2003, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 93.56452942],
    ['Philippines', 'PHL', 2000, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 92.65490723],
    ['Philippines', 'PHL', 1994, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 94.53865051],
    ['Philippines', 'PHL', 1990, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 93.18071747],
    ['Philippines', 'PHL', 1980, 'Literacy rate, adult female (% of females ages 15 and above)', 'SE.ADT.LITR.FE.ZS', 82.76215363],
    ['Philippines', 'PHL', 2019, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 95.70572662],
    ['Philippines', 'PHL', 2015, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 98.12325287],
    ['Philippines', 'PHL', 2013, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 96.00833893],
    ['Philippines', 'PHL', 2008, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 95.01213074],
    ['Philippines', 'PHL', 2003, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 91.63449097],
    ['Philippines', 'PHL', 2000, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 92.54499817],
    ['Philippines', 'PHL', 1994, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 93.30285645],
    ['Philippines', 'PHL', 1990, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 93.97168732],
    ['Philippines', 'PHL', 1980, 'Literacy rate, adult male (% of males ages 15 and above)', 'SE.ADT.LITR.MA.ZS', 83.88928986],
    ['Philippines', 'PHL', 2021, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.976957738],
    ['Philippines', 'PHL', 2020, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.976088405],
    ['Philippines', 'PHL', 2019, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.970158875],
    ['Philippines', 'PHL', 2018, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.962437928],
    ['Philippines', 'PHL', 2017, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.964394212],
    ['Philippines', 'PHL', 2016, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.966678143],
    ['Philippines', 'PHL', 2015, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.970080018],
    ['Philippines', 'PHL', 2014, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.979579985],
    ['Philippines', 'PHL', 2009, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.988849998],
    ['Philippines', 'PHL', 2008, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.990239978],
    ['Philippines', 'PHL', 2007, 'School enrollment, primary (gross), gender parity index (GPI)', 'SE.ENR.PRIM.FM.ZS', 0.987600029]
]

# Create a DataFrame
df = pd.DataFrame(data, columns=['Country', 'Country Code', 'Year', 'Indicator Name', 'Indicator Code', 'Value'])

# Separate data for different indicators
indicator1 = df[df['Indicator Code'] == 'SE.ADT.1524.LT.MA.ZS']
indicator2 = df[df['Indicator Code'] == 'SE.ADT.LITR.FE.ZS']
indicator3 = df[df['Indicator Code'] == 'SE.ADT.LITR.MA.ZS']
indicator4 = df[df['Indicator Code'] == 'SE.ENR.PRIM.FM.ZS']

# Plotting the graphs
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(indicator1['Year'], indicator1['Value'], marker='o')
plt.title('Literacy rate, youth male')
plt.xlabel('Year')
plt.ylabel('% of males ages 15-24')

plt.subplot(2, 2, 2)
plt.plot(indicator2['Year'], indicator2['Value'], marker='o')
plt.title('Literacy rate, adult female')
plt.xlabel('Year')
plt.ylabel('% of females ages 15 and above')

plt.subplot(2, 2, 3)
plt.plot(indicator3['Year'], indicator3['Value'], marker='o')
plt.title('Literacy rate, adult male')
plt.xlabel('Year')
plt.ylabel('% of males ages 15 and above')

plt.subplot(2, 2, 4)
plt.plot(indicator4['Year'], indicator4['Value'], marker='o')
plt.title('School enrollment, primary (gross), gender parity index (GPI)')
plt.xlabel('Year')
plt.ylabel('Gender Parity Index')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

data = [
    ['Philippines', 'PHL', 2003, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 27.68600082],
    ['Philippines', 'PHL', 2002, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 27.41799927],
    ['Philippines', 'PHL', 2001, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 27.23800087],
    ['Philippines', 'PHL', 2000, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 27.57799911],
    ['Philippines', 'PHL', 1999, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 27.73200035],
    ['Philippines', 'PHL', 1998, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 26.90699959],
    ['Philippines', 'PHL', 1997, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 29.1060009],
    ['Philippines', 'PHL', 1996, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 29.3920002],
    ['Philippines', 'PHL', 1995, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 27.56900024],
    ['Philippines', 'PHL', 1994, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 27.40500069],
    ['Philippines', 'PHL', 1993, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 26.875],
    ['Philippines', 'PHL', 1992, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 26.68600082],
    ['Philippines', 'PHL', 1991, 'Own-account workers, female (% of female employment) (modeled ILO estimate)', 'SL.EMP.OWAC.FE.ZS', 26.36400032],
    ['Philippines', 'PHL', 2016, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 26.51099968],
    ['Philippines', 'PHL', 2015, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 26.77799988],
    ['Philippines', 'PHL', 2014, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 28.83399963],
    ['Philippines', 'PHL', 2013, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 28.45899963],
    ['Philippines', 'PHL', 2012, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 28.92399979],
    ['Philippines', 'PHL', 2011, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 30.69199944],
    ['Philippines', 'PHL', 2010, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 31.38699913],
    ['Philippines', 'PHL', 2009, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 31.9829998],
    ['Philippines', 'PHL', 2008, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 32.81000137],
    ['Philippines', 'PHL', 2007, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 33.01900101],
    ['Philippines', 'PHL', 2006, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 33.42200089],
    ['Philippines', 'PHL', 2005, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 33.52099991],
    ['Philippines', 'PHL', 2004, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 33.58200073],
    ['Philippines', 'PHL', 2003, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 34.01800156],
    ['Philippines', 'PHL', 2002, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 34.11800003],
    ['Philippines', 'PHL', 2001, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 34.29100037],
    ['Philippines', 'PHL', 2000, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 34.04199982],
    ['Philippines', 'PHL', 1999, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 34.29499817],
    ['Philippines', 'PHL', 1998, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 34.03699875],
    ['Philippines', 'PHL', 1997, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 32.81100082],
    ['Philippines', 'PHL', 1996, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 32.34899902],
    ['Philippines', 'PHL', 1995, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 30.41799927],
    ['Philippines', 'PHL', 1994, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 30.30900002],
    ['Philippines', 'PHL', 1993, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 30.61499977],
    ['Philippines', 'PHL', 1992, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 30.43600082],
    ['Philippines', 'PHL', 1991, 'Own-account workers, male (% of male employment) (modeled ILO estimate)', 'SL.EMP.OWAC.MA.ZS', 30.12599945],
]

columns = ['Country', 'Country Code', 'Year', 'Indicator', 'Indicator Code', 'Value']

df = pd.DataFrame(data, columns=columns)
import matplotlib.pyplot as plt

# Filter the DataFrame for female employment data
female_data = df[df['Indicator'].str.contains('female')]

# Plot the female employment data
plt.plot(female_data['Year'], female_data['Value'], label='Female Employment')

# Add labels and title to the graph
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Female Employment in the Philippines')

# Display the legend
plt.legend()

# Show the graph
plt.show()
# !pip install pandas matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
